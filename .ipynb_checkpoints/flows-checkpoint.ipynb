# %%
import subprocess
import re
from functools import partial
from matplotlib import pyplot as plt

# %%
subprocess.run("make", shell=True)
# Out:
# CompletedProcess(args='make', returncode=0)

# %%
timeout = 10
def get_avg_time(obj, n=10, m=100, c=1000, num=20, global_heuristic_flag=-1):
    tot_time = 0
    for i in range(num):
        if(global_heuristic_flag == -1):
            out = subprocess.check_output("./create_graph {} {} {} > graph.txt && ./{} graph.txt".format(n, m, c, obj), 
                                shell=True, timeout = timeout)
        else:
            out = subprocess.check_output("./create_graph {} {} {} > graph.txt && ./{} graph.txt 1".format(n, m, c, obj), 
                                shell=True, timeout = timeout)
        out = str(out, 'utf-8')
        time = float(re.split('\n|:',out)[-2])
        tot_time += time
        
    return tot_time / num

flow_names = ["Ford Fulkerson (CPU)", "Edmond Karp (CPU)", "Ford Fulkerson (GPU)", "Edmond Karp (GPU)", 
              "Push Relabel w/o Global relabel (GPU)", "Push Relabel w/ Global relabel (GPU)"]
flow_functions = [
    partial(get_avg_time, "ford_fulkerson_cpu"),
    partial(get_avg_time, "edmond_karp_cpu"),
    partial(get_avg_time, "ford_fulkerson_gpu"),
    partial(get_avg_time, "edmond_karp_gpu"),
    partial(get_avg_time,"push_relabel_gpu",global_heuristic_flag=0),
    partial(get_avg_time,"push_relabel_gpu",global_heuristic_flag=1)
]
flow_colors = ['k','g','b','r','c','m']

# %%
# Varying number of edges while keeping number of vertices fixed (to 100)
for i in range(6):
    name = flow_names[i]
    foo = flow_functions[i]
    color = flow_colors[i]
    print('Method: {}'.format(name))
    n = 100
    m = 100
    times = []
    edges = []
    while(m <= 1000000):
        print('|E|: {}'.format(m))
        try:
            t = foo(n, m)
            times.append(t)
            edges.append(m)
        except:
            times.append(timeout)
            edges.append(m)
            break
        m *= 2
    plt.plot(edges, times, color, label = name)
plt.xscale("log")
plt.title('Time v/s |E|, |V| = 100, Max. Capacity 1000')
plt.xlabel('|E|, number of edges')
plt.ylabel('Time (in sec)')
plt.legend()
plt.show()
# Out:
# Method: Ford Fulkerson (CPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# Method: Edmond Karp (CPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# Method: Ford Fulkerson (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Edmond Karp (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Push Relabel w/o Global relabel (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Push Relabel w/ Global relabel (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200

# %%
# Varying number of edges while keeping number of vertices fixed (to 10000)
for i in range(6):
    name = flow_names[i]
    foo = flow_functions[i]
    color = flow_colors[i]
    print('Method: {}'.format(name))
    n = 10000
    m = 100
    times = []
    edges = []
    while(m <= 1000000):
        print('|E|: {}'.format(m))
        try:
            t = foo(n, m)
            times.append(t)
            edges.append(m)
        except:
            times.append(timeout)
            edges.append(m)
            break
        m *= 2
    plt.plot(edges, times, color, label = name)
plt.xscale("log")
plt.title('Time v/s |E|, |V| = 10000, Max. Capacity 1000')
plt.xlabel('|E|, number of edges')
plt.ylabel('Time (in sec)')
plt.legend()
plt.show()
# Out:
# Method: Ford Fulkerson (CPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# Method: Edmond Karp (CPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Ford Fulkerson (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Edmond Karp (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Push Relabel w/o Global relabel (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# Method: Push Relabel w/ Global relabel (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400

# %%
# Varying number of edges while keeping number of vertices fixed (to 1000000)
for i in range(6):
    name = flow_names[i]
    foo = flow_functions[i]
    color = flow_colors[i]
    print('Method: {}'.format(name))
    n = 1000000
    m = 100
    times = []
    edges = []
    while(m <= 1000000):
        print('|E|: {}'.format(m))
        try:
            t = foo(n, m)
            times.append(t)
            edges.append(m)
        except:
            times.append(timeout)
            edges.append(m)
            break
        m *= 2
    plt.plot(edges, times, color, label = name)
plt.xscale("log")
plt.title('Time v/s |E|, |V| = 1000000, Max. Capacity 1000')
plt.xlabel('|E|, number of edges')
plt.ylabel('Time (in sec)')
plt.legend()
plt.show()
# Out:
# Method: Ford Fulkerson (CPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Edmond Karp (CPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Ford Fulkerson (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Edmond Karp (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
# |E|: 819200
# Method: Push Relabel w/o Global relabel (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# Method: Push Relabel w/ Global relabel (GPU)
# |E|: 100
# |E|: 200
# |E|: 400
# |E|: 800
# |E|: 1600
# |E|: 3200
# |E|: 6400
# |E|: 12800
# |E|: 25600
# |E|: 51200
# |E|: 102400
# |E|: 204800
# |E|: 409600
